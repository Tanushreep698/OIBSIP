# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanushreep698/OIBSIP/blob/main/Copy_of_project3level1ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📦 Step 1: Install and Import Libraries
# !pip install missingno

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

# 📂 Step 2: Load the Dataset
# Replace with your actual file path or upload manually in Colab
from google.colab import files
uploaded = files.upload()

# Assuming CSV file
df = pd.read_csv(next(iter(uploaded)))

# 🔍 Step 3: Initial Exploration
print("Shape of dataset:", df.shape)
print("\nData Types:\n", df.dtypes)
print("\nMissing Values:\n", df.isnull().sum())
print("\nSummary Statistics:\n", df.describe(include='all'))

# 📊 Visualize Missing Data
msno.matrix(df)
plt.show()

# 🧹 Step 4: Handle Missing Data
# Example: Drop columns with more than 50% missing values
threshold = len(df) * 0.5
df = df.dropna(thresh=threshold, axis=1)

# Example: Fill missing numerical values with median
num_cols = df.select_dtypes(include=np.number).columns
df[num_cols] = df[num_cols].fillna(df[num_cols].median())
# Out:
# ...
#      <input type="file" id="files-57278ca2-7504-4fdd-8ba0-4ca25a7dbf54" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-57278ca2-7504-4fdd-8ba0-4ca25a7dbf54">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
